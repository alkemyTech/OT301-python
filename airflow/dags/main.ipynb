# %%
import pandas as pd
from os import path

# %%
path_dags = path.dirname(path.realpath('__main.ipynb__')) #Guardo la dirección de este .py
name_un = 'GBUSalvador'
df = pd.read_csv(path_dags.replace('/dags',f'/files/{name_un}_select.csv'))
df
# Out:
#       Unnamed: 0                university  \
# 0              0  UNIVERSIDAD_DEL_SALVADOR
# 1              1  UNIVERSIDAD_DEL_SALVADOR
# 2              2  UNIVERSIDAD_DEL_SALVADOR
# 3              3  UNIVERSIDAD_DEL_SALVADOR
# 4              4  UNIVERSIDAD_DEL_SALVADOR
# ...          ...                       ...
# 1899        1899  UNIVERSIDAD_DEL_SALVADOR
# 1900        1900  UNIVERSIDAD_DEL_SALVADOR
# 1901        1901  UNIVERSIDAD_DEL_SALVADOR
# 1902        1902  UNIVERSIDAD_DEL_SALVADOR
# 1903        1903  UNIVERSIDAD_DEL_SALVADOR
#
#                                                  career inscription_date  \
# 0                       LICENCIATURA_EN_ADMINISTRACIÓN_        17-Sep-20
# 1               LICENCIATURA_EN_RELACIONES_DEL_TRABAJO_        01-Oct-20
# 2                  LICENCIATURA_EN_CIENCIAS_AMBIENTALES        29-Sep-20
# 3     LICENCIATURA_EN_CIENCIA_Y_TECNOLOGÍA_DE_ALIMENTOS        21-Dec-20
# 4                   LICENCIATURA_EN_TERAPIA_OCUPACIONAL        15-Jan-21
# ...                                                 ...              ...
# 1899                      LICENCIATURA_EN_MUSICOTERAPIA        18-Oct-20
# 1900                                          ACTUARIO_        04-Sep-20
# 1901          LICENCIATURA_EN_PRODUCCIÓN_DE_BIOIMAGENES        20-Nov-20
# 1902                  LICENCIATURA_EN_CIENCIA_POLÍTICA_        11-Sep-20
# 1903                                         BIOQUÍMICA        07-Nov-20
#
#      first_name            last_name gender  age  postal_code  \
# 0                     JAMES_GONZALEZ      M   -1           -1
# 1                CHRISTOPHER_RUSSELL      M   -1           -1
# 2                      MONICA_FARLEY      F   -1           -1
# 3                       TAMMY_SUTTON      F   -1           -1
# 4                       SYDNEY_PRICE      F   -1           -1
# ...         ...                  ...    ...  ...          ...
# 1899                    EDWARD_GOMEZ      M   -1           -1
# 1900                    STACEY_MEYER      F   -1           -1
# 1901                     CHAD_KELLEY      M   -1           -1
# 1902                   BRYCE_NAVARRO      M   -1           -1
# 1903                  RICARDO_MORRIS      M   -1           -1
#
#                location                      email
# 0       CORONEL_ISLEÑOS  JOSEPHJACKSON@HOTMAIL.COM
# 1               BELLOCQ  PATTERSONJEREMY@GMAIL.COM
# 2           CAÑADA_RICA          MARIA48@YAHOO.COM
# 3      FRANCISCO_MADERO      CHARLES28@HOTMAIL.COM
# 4            PELLEGRINI  SINGLETONJOSHUA@YAHOO.COM
# ...                 ...                        ...
# 1899  ALDEA_MARIA_LUISA      BROWNSERGIO@YAHOO.COM
# 1900            LA_SARA         GANTHONY@YAHOO.COM
# 1901           SAN_JOSE        GHARRIS@HOTMAIL.COM
# 1902          ASCENCION    BROWNSYDNEY@HOTMAIL.COM
# 1903          BONIFACIO        QDUDLEY@HOTMAIL.COM
#
# [1904 rows x 11 columns]
