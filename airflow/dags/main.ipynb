# %%
import pandas as pd
from os import path

# %%
path_dags = path.dirname(path.realpath('__main.ipynb__')) #Guardo la dirección de este .py
name_un = 'GBUNComahue'
df = pd.read_csv(path_dags.replace('/dags',f'/files/{name_un}_select.csv'))

#Correción de formato de texto
df['university'] = df['university'].str.lower()
df['university'] = df['university'].str.replace('_',' ')
df['career'] = df['career'].str.lower()
df['career'] = df['career'].str.replace('_',' ')
df['last_name'] = df['last_name'].str.lower()
df['last_name'] = df['last_name'].str.replace('_',' ')
df['gender'] = df['gender'].str.replace('M','male')
df['gender'] = df['gender'].str.replace('F','female')
df['email'] = df['email'].str.lower()
df
# Out:
#       Unnamed: 0                  university  \
# 0              0  univ. nacional del comahue
# 1              1  univ. nacional del comahue
# 2              2  univ. nacional del comahue
# 3              3  univ. nacional del comahue
# 4              4  univ. nacional del comahue
# ...          ...                         ...
# 2065        2065  univ. nacional del comahue
# 2066        2066  univ. nacional del comahue
# 2067        2067  univ. nacional del comahue
# 2068        2068  univ. nacional del comahue
# 2069        2069  univ. nacional del comahue
#
#                                                  career inscription_date  \
# 0                                     diseño industrial       2020-11-20
# 1                                     contador público        2020-10-31
# 2                  licenciatura en ciencias ambientales       2020-09-04
# 3                                             agronomía       2021-01-31
# 4                                     diseño industrial       2020-12-03
# ...                                                 ...              ...
# 2065  licenciatura en ciencia y tecnología de alimentos       2020-12-06
# 2066                                          actuario        2020-09-03
# 2067           licenciatura en kinesiología y fisiatría       2020-12-02
# 2068                                       arquitectura       2020-12-04
# 2069                    licenciatura en administración        2020-12-22
#
#      first_name           last_name  gender  age  postal_code location  \
# 0                   michelle harris  female   -1         7261
# 1                       amanda hill  female   -1         8129
# 2                      jason montes    male   -1         3194
# 3                        ryan davis    male   -1         3328
# 4                     sandra burton  female   -1         4500
# ...         ...                 ...     ...  ...          ...      ...
# 2065                  david santana    male   -1         6317
# 2066                natalie gilbert  female   -1         3134
# 2067                      jay ellis    male   -1         7305
# 2068             stephen harrington    male   -1         6307
# 2069               christopher bell    male   -1         1757
#
#                            email fecha_nacimiento
# 0       martinezjohn@hotmail.com       1917-10-13
# 1            tyler57@hotmail.com       1990-04-08
# 2            wbryant@hotmail.com       1925-08-09
# 3       patriciazamora@gmail.com       1934-12-23
# 4          kleinlauren@gmail.com       1970-02-12
# ...                          ...              ...
# 2065  rebeccajohnson@hotmail.com       1918-08-09
# 2066     cowanjennifer@gmail.com       1944-11-05
# 2067      smithjessica@gmail.com       1945-02-20
# 2068      francesmiles@gmail.com       1933-01-02
# 2069         egallegos@yahoo.com       2008-02-07
#
# [2070 rows x 12 columns]

# %%
df['age'] = pd.to_datetime(df.inscription_date) - pd.to_datetime(df.fecha_nacimiento)
df['age']=df.age.astype(int)
df['age'] = (df.age / (10**9) / 3600 / 24 /365.2425).astype(int)

# %%
pd.to_datetime(df.fecha_nacimiento).sort_values()
# Out:
# 640    1905-11-21
# 1166   1905-12-16
# 1786   1905-12-20
# 1986   1906-01-11
# 683    1906-01-19
#           ...
# 872    2021-07-09
# 820    2021-07-22
# 832    2021-09-23
# 812    2021-10-26
# 241    2021-11-02
# Name: fecha_nacimiento, Length: 2070, dtype: datetime64[ns]

# %%
df.age.describe()
# Out:
# count    2070.000000
# mean       56.564734
# std        33.853627
# min        -1.000000
# 25%        27.000000
# 50%        56.000000
# 75%        86.000000
# max       115.000000
# Name: age, dtype: float64

# %%
df2 = pd.read_csv(path_dags.replace('/dags',f'/assets/codigos_postales.csv'))
df2.localidad = df2.localidad.str.lower()
df2
# Out:
#       codigo_postal                     localidad
# 0              1601            isla martin garcia
# 1              1602                       florida
# 2              1603                villa martelli
# 3              1605                    carapachay
# 4              1607                 villa adelina
# ...             ...                           ...
# 1515           9409             isla gran malvina
# 1516           9410                bahia lapataia
# 1517           9411  base aerea teniente matienzo
# 1518           9420             aserradero arroyo
# 1519           9421               frigorifico cap
#
# [1520 rows x 2 columns]

# %%
count = 0
for x in df.postal_code:
    index_df2 = df2.index[df2['codigo_postal'] == x][0]
    df.location[count] = df2.localidad[index_df2]
    count = count + 1
df
# Out:
# /tmp/ipykernel_3161/413148739.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.location[count] = df2.localidad[index_df2]
#       Unnamed: 0                  university  \
# 0              0  univ. nacional del comahue
# 1              1  univ. nacional del comahue
# 2              2  univ. nacional del comahue
# 3              3  univ. nacional del comahue
# 4              4  univ. nacional del comahue
# ...          ...                         ...
# 2065        2065  univ. nacional del comahue
# 2066        2066  univ. nacional del comahue
# 2067        2067  univ. nacional del comahue
# 2068        2068  univ. nacional del comahue
# 2069        2069  univ. nacional del comahue
#
#                                                  career inscription_date  \
# 0                                     diseño industrial       2020-11-20
# 1                                     contador público        2020-10-31
# 2                  licenciatura en ciencias ambientales       2020-09-04
# 3                                             agronomía       2021-01-31
# 4                                     diseño industrial       2020-12-03
# ...                                                 ...              ...
# 2065  licenciatura en ciencia y tecnología de alimentos       2020-12-06
# 2066                                          actuario        2020-09-03
# 2067           licenciatura en kinesiología y fisiatría       2020-12-02
# 2068                                       arquitectura       2020-12-04
# 2069                    licenciatura en administración        2020-12-22
#
#      first_name           last_name  gender  age  postal_code  \
# 0                   michelle harris  female  103         7261
# 1                       amanda hill  female   30         8129
# 2                      jason montes    male   95         3194
# 3                        ryan davis    male   86         3328
# 4                     sandra burton  female   50         4500
# ...         ...                 ...     ...  ...          ...
# 2065                  david santana    male  102         6317
# 2066                natalie gilbert  female   75         3134
# 2067                      jay ellis    male   75         7305
# 2068             stephen harrington    male   87         6307
# 2069               christopher bell    male   12         1757
#
#                    location                       email fecha_nacimiento
# 0           saladillo norte    martinezjohn@hotmail.com       1917-10-13
# 1              17 de agosto         tyler57@hotmail.com       1990-04-08
# 2            paso telegrafo         wbryant@hotmail.com       1925-08-09
# 3          colonia japonesa    patriciazamora@gmail.com       1934-12-23
# 4        alto del saladillo       kleinlauren@gmail.com       1970-02-12
# ...                     ...                         ...              ...
# 2065           la florencia  rebeccajohnson@hotmail.com       1918-08-09
# 2066      antonio tomas sud     cowanjennifer@gmail.com       1944-11-05
# 2067   antonio de los heros      smithjessica@gmail.com       1945-02-20
# 2068     colonia la oracion      francesmiles@gmail.com       1933-01-02
# 2069  gregorio de laferrere         egallegos@yahoo.com       2008-02-07
#
# [2070 rows x 12 columns]

# %%
df = df.drop(['Unnamed: 0','fecha_nacimiento'], axis=1)
df
# Out:
#                       university  \
# 0     univ. nacional del comahue
# 1     univ. nacional del comahue
# 2     univ. nacional del comahue
# 3     univ. nacional del comahue
# 4     univ. nacional del comahue
# ...                          ...
# 2065  univ. nacional del comahue
# 2066  univ. nacional del comahue
# 2067  univ. nacional del comahue
# 2068  univ. nacional del comahue
# 2069  univ. nacional del comahue
#
#                                                  career inscription_date  \
# 0                                     diseño industrial       2020-11-20
# 1                                     contador público        2020-10-31
# 2                  licenciatura en ciencias ambientales       2020-09-04
# 3                                             agronomía       2021-01-31
# 4                                     diseño industrial       2020-12-03
# ...                                                 ...              ...
# 2065  licenciatura en ciencia y tecnología de alimentos       2020-12-06
# 2066                                          actuario        2020-09-03
# 2067           licenciatura en kinesiología y fisiatría       2020-12-02
# 2068                                       arquitectura       2020-12-04
# 2069                    licenciatura en administración        2020-12-22
#
#      first_name           last_name  gender  age  postal_code  \
# 0                   michelle harris  female  103         7261
# 1                       amanda hill  female   30         8129
# 2                      jason montes    male   95         3194
# 3                        ryan davis    male   86         3328
# 4                     sandra burton  female   50         4500
# ...         ...                 ...     ...  ...          ...
# 2065                  david santana    male  102         6317
# 2066                natalie gilbert  female   75         3134
# 2067                      jay ellis    male   75         7305
# 2068             stephen harrington    male   87         6307
# 2069               christopher bell    male   12         1757
#
#                    location                       email
# 0           saladillo norte    martinezjohn@hotmail.com
# 1              17 de agosto         tyler57@hotmail.com
# 2            paso telegrafo         wbryant@hotmail.com
# 3          colonia japonesa    patriciazamora@gmail.com
# 4        alto del saladillo       kleinlauren@gmail.com
# ...                     ...                         ...
# 2065           la florencia  rebeccajohnson@hotmail.com
# 2066      antonio tomas sud     cowanjennifer@gmail.com
# 2067   antonio de los heros      smithjessica@gmail.com
# 2068     colonia la oracion      francesmiles@gmail.com
# 2069  gregorio de laferrere         egallegos@yahoo.com
#
# [2070 rows x 10 columns]

# %%
with open(path_dags.replace('/dags',f'/datasets/{name_un}_process.txt'), 'a') as f:
    dfAsString = df.to_string(header=True, index=False)
    f.write(dfAsString)
    f.close()
